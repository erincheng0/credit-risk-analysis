# %%
from src.data_prep import (
    load_loan_default,
    clean_loan_default,
    engineer_features_loan_default,
    load_credit_risk,
    clean_credit_risk,
    engineer_features_credit_risk,
)
from src.eda import basic_summary, plot_default_rate, kde_by_target

# %%
# load and prep

loan_path = "/Users/erincheng/Desktop/credit-risk-analysis/data/raw/Loan_default.csv"
credit_path = "/Users/erincheng/Desktop/credit-risk-analysis/data/raw/credit_risk_dataset.csv"

df_loans = load_loan_default(loan_path)
df_loans_clean = clean_loan_default(df_loans)
df_loans_fe = engineer_features_loan_default(df_loans_clean)

df_credit = load_credit_risk(credit_path)
df_credit_clean = clean_credit_risk(df_credit)
df_credit_fe = engineer_features_credit_risk(df_credit_clean)
# Out:
# /Users/erincheng/Desktop/credit-risk-analysis/src/data_prep.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype("category")
# /Users/erincheng/Desktop/credit-risk-analysis/src/data_prep.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype("category")
# /Users/erincheng/Desktop/credit-risk-analysis/src/data_prep.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype("category")
# /Users/erincheng/Desktop/credit-risk-analysis/src/data_prep.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype("category")
# /Users/erincheng/Desktop/credit-risk-analysis/src/data_prep.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_numeric(df[col], errors="coerce")
# /Users/erincheng/Desktop/credit-risk-analysis/src/data_prep.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["person_emp_length"] = df["person_emp_length"].fillna(
# /Users/erincheng/Desktop/credit-risk-analysis/src/data_prep.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["loan_int_rate"] = df["loan_int_rate"].fillna(

# %%
# EDA: loan default

basic_summary(df_loans_fe, target="Default")
plot_default_rate(df_loans_fe, "AgeBand", "Default", "Default rate by Age Band", rotation=0)
plot_default_rate(df_loans_fe, "DTI_Bucket", "Default", "Default rate by DTI bucket", rotation=0)
kde_by_target(df_loans_fe, "DTIRatio", "Default")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   LoanID              255347 non-null  object
#  1   Age                 255347 non-null  int64
#  2   Income              255347 non-null  int64
#  3   LoanAmount          255347 non-null  int64
#  4   CreditScore         255347 non-null  int64
#  5   MonthsEmployed      255347 non-null  int64
#  6   NumCreditLines      255347 non-null  int64
#  7   InterestRate        255347 non-null  float64
#  8   LoanTerm            255347 non-null  int64
#  9   DTIRatio            255347 non-null  float64
#  10  Education           255347 non-null  category
#  11  EmploymentType      255347 non-null  category
#  12  MaritalStatus       255347 non-null  category
#  13  HasMortgage         255347 non-null  category
#  14  HasDependents       255347 non-null  category
#  15  LoanPurpose         255347 non-null  category
#  16  HasCoSigner         255347 non-null  category
#  17  Default             255347 non-null  int64
#  18  AgeBand             255347 non-null  category
#  19  IncomeBand          255347 non-null  category
#  20  LoanAmtBand         255347 non-null  category
#  21  DTI_Bucket          255347 non-null  category
#  22  EmpLengthBucket     255347 non-null  category
#  23  ManyCreditLines     255347 non-null  int64
#  24  HighDTI_LargeLoan   255347 non-null  int64
#  25  HasMortgage_Flag    255347 non-null  int64
#  26  HasDependents_Flag  255347 non-null  int64
#  27  HasCoSigner_Flag    255347 non-null  int64
# dtypes: category(12), float64(2), int64(13), object(1)
# memory usage: 34.1+ MB
# None
#             LoanID            Age         Income     LoanAmount  \
# count       255347  255347.000000  255347.000000  255347.000000
# unique      255347            NaN            NaN            NaN
# top     I38PQUQS96            NaN            NaN            NaN
# freq             1            NaN            NaN            NaN
# mean           NaN      43.498306   82499.304597  127578.865512
# std            NaN      14.990258   38963.013729   70840.706142
# min            NaN      18.000000   15000.000000    5000.000000
# 25%            NaN      31.000000   48825.500000   66156.000000
# 50%            NaN      43.000000   82466.000000  127556.000000
# 75%            NaN      56.000000  116219.000000  188985.000000
# max            NaN      69.000000  149999.000000  249999.000000
#
#           CreditScore  MonthsEmployed  NumCreditLines   InterestRate  \
# count   255347.000000   255347.000000   255347.000000  255347.000000
# unique            NaN             NaN             NaN            NaN
# top               NaN             NaN             NaN            NaN
# freq              NaN             NaN             NaN            NaN
# mean       574.264346       59.541976        2.501036      13.492802
# std        158.903867       34.643376        1.117018       6.632646
# min        300.000000        0.000000        1.000000       2.230000
# 25%        437.000000       30.000000        2.000000       7.770000
# 50%        574.000000       60.000000        2.000000      13.460000
# 75%        712.000000       90.000000        3.000000      19.250000
# max        849.000000      119.000000        4.000000      24.780000
#
#              LoanTerm       DTIRatio  ... AgeBand IncomeBand LoanAmtBand  \
# count   255347.000000  255347.000000  ...  255347     255347      255347
# unique            NaN            NaN  ...       6          4           4
# top               NaN            NaN  ...   26–35   Med-High       Small
# freq              NaN            NaN  ...   49408      63839       63838
# mean        36.025894       0.500212  ...     NaN        NaN         NaN
# std         16.969330       0.230701  ...     NaN        NaN         NaN
# min         12.000000       0.110000  ...     NaN        NaN         NaN
# 25%         24.000000       0.300000  ...     NaN        NaN         NaN
# 50%         36.000000       0.500000  ...     NaN        NaN         NaN
# 75%         48.000000       0.700000  ...     NaN        NaN         NaN
# max         60.000000       0.890000  ...     NaN        NaN         NaN
#
#        DTI_Bucket EmpLengthBucket ManyCreditLines HighDTI_LargeLoan  \
# count      255347          255347        255347.0     255347.000000
# unique          4               4             NaN               NaN
# top          >40%         5–10yrs             NaN               NaN
# freq       157978          125582             NaN               NaN
# mean          NaN             NaN             0.0          0.372536
# std           NaN             NaN             0.0          0.483481
# min           NaN             NaN             0.0          0.000000
# 25%           NaN             NaN             0.0          0.000000
# 50%           NaN             NaN             0.0          0.000000
# 75%           NaN             NaN             0.0          1.000000
# max           NaN             NaN             0.0          1.000000
#
#         HasMortgage_Flag HasDependents_Flag HasCoSigner_Flag
# count      255347.000000      255347.000000    255347.000000
# unique               NaN                NaN              NaN
# top                  NaN                NaN              NaN
# freq                 NaN                NaN              NaN
# mean            0.500014           0.500268         0.500108
# std             0.500001           0.500001         0.500001
# min             0.000000           0.000000         0.000000
# 25%             0.000000           0.000000         0.000000
# 50%             1.000000           1.000000         1.000000
# 75%             1.000000           1.000000         1.000000
# max             1.000000           1.000000         1.000000
#
# [11 rows x 28 columns]
#
# Target distribution:
# Default
# 0    0.883872
# 1    0.116128
# Name: proportion, dtype: float64
# /Users/erincheng/Desktop/credit-risk-analysis/src/eda.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(col)[target]
# /Users/erincheng/Desktop/credit-risk-analysis/src/eda.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(col)[target]
